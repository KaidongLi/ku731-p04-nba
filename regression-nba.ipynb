# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d_ori = pd.read_csv('data/nba_elo.csv')
#data = data.dropna()
#d_ori
d_ori.sample(2)
# Out:
#              date  season  neutral playoff team1 team2   elo1_pre   elo2_pre  \
# 23414  1982-02-19    1982        0     NaN   DEN   SAS  1523.7214  1569.0496
# 60435  2013-04-17    2013        0     NaN   SAC   LAC  1413.7845  1636.0679
#
#        elo_prob1  elo_prob2   ...    carm-elo1_post  carm-elo2_post  \
# 23414   0.578036   0.421964   ...               NaN             NaN
# 60435   0.330944   0.669056   ...               NaN             NaN
#
#        carm-elo_prob1  carm-elo_prob2  carmelo1_pre  carmelo2_pre  \
# 23414             NaN             NaN           NaN           NaN
# 60435             NaN             NaN           NaN           NaN
#
#        carmelo_prob1  carmelo_prob2  score1  score2
# 23414            NaN            NaN   121.0   126.0
# 60435            NaN            NaN   108.0   112.0
#
# [2 rows x 24 columns]

# %% [markdown]
# At the first glance, we notice there are many NaN values in the data. So we want a count of how many NaN rows each of the columns has. And we want to develop a strategy to handle it.
#
# There are a total of 68,324 rows and 24 columns. So we have some columns with more than 60,000 rows of NaN. Apparently the best way is to discard the column as a whole. For columns with less NaN rows, we will just discard those rows.

# %%
coln_null = d_ori.columns[d_ori.isnull().any()]
d_ori[coln_null].isnull().sum()
# Out:
# playoff           64044
# elo1_post          1191
# elo2_post          1191
# carm-elo1_pre     63157
# carm-elo2_pre     63157
# carm-elo1_post    64348
# carm-elo2_post    64348
# carm-elo_prob1    63157
# carm-elo_prob2    63157
# carmelo1_pre      67094
# carmelo2_pre      67094
# carmelo_prob1     67094
# carmelo_prob2     67094
# score1             1191
# score2             1191
# dtype: int64

# %%
data_pro = d_ori.drop(columns=['playoff', 'carm-elo1_pre', 'carm-elo2_pre', 'carm-elo1_post', 'carm-elo2_post', 'carm-elo_prob1', 'carm-elo_prob2', 'carmelo1_pre', 'carmelo2_pre', 'carmelo_prob1', 'carmelo_prob2'])
data_pro = data_pro.dropna()
data_pro
# Out:
#              date  season  neutral team1 team2     elo1_pre     elo2_pre  \
# 0      1946-11-01    1947        0   TRH   NYK  1300.000000  1300.000000
# 1      1946-11-02    1947        0   CHS   NYK  1300.000000  1306.723300
# 2      1946-11-02    1947        0   PRO   BOS  1300.000000  1300.000000
# 3      1946-11-02    1947        0   STB   PIT  1300.000000  1300.000000
# 4      1946-11-02    1947        0   DTF   WSC  1300.000000  1300.000000
# 5      1946-11-03    1947        0   CLR   TRH  1300.000000  1293.276700
# 6      1946-11-04    1947        0   PIT   WSC  1295.309200  1320.381100
# 7      1946-11-05    1947        0   BOS   CHS  1294.845800  1309.652100
# 8      1946-11-05    1947        0   DTF   STB  1279.618900  1304.690800
# 9      1946-11-07    1947        0   PHW   PIT  1300.000000  1277.945600
# 10     1946-11-07    1947        0   PRO   CHS  1305.154200  1316.084000
# 11     1946-11-07    1947        0   STB   NYK  1312.847300  1297.071200
# 12     1946-11-08    1947        0   TRH   DTF  1286.153400  1271.462400
# 13     1946-11-09    1947        0   PRO   PIT  1311.503200  1273.278600
# 14     1946-11-09    1947        0   STB   WSC  1302.598800  1337.744800
# 15     1946-11-09    1947        0   CHS   TRH  1309.735000  1289.169100
# 16     1946-11-09    1947        0   DTF   BOS  1268.446800  1288.413900
# 17     1946-11-10    1947        0   CLR   WSC  1307.123300  1334.611200
# 18     1946-11-11    1947        0   NYK   CHS  1307.319700  1315.252200
# 19     1946-11-11    1947        0   PIT   PRO  1267.467400  1317.314300
# 20     1946-11-13    1947        0   CHS   BOS  1329.355800  1275.276700
